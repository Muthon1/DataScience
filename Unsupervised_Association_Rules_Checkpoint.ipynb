# %% [markdown]
# <a href="https://colab.research.google.com/github/Muthon1/DataScience/blob/main/Unsupervised_Association_Rules_Checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# !pip install apyori
from apyori import apriori
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ...

# %%
# Toy dataset
toy_dataset = [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],
               ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],
               ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],
               ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],
               ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]

# Apply Apriori algorithm
rules = apriori(toy_dataset, min_support=0.2, min_confidence=0.7, min_lift=1.0)

# Convert rules into a list
results = list(rules)

# Print the results
for result in results:
    print(result)
# Out:
# RelationRecord(items=frozenset({'Pants'}), support=0.8, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Pants'}), confidence=0.8, lift=1.0)])
# RelationRecord(items=frozenset({'Scarf'}), support=0.8, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Scarf'}), confidence=0.8, lift=1.0)])
# RelationRecord(items=frozenset({'Dress', 'Heels'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Dress'}), items_add=frozenset({'Heels'}), confidence=1.0, lift=2.5), OrderedStatistic(items_base=frozenset({'Heels'}), items_add=frozenset({'Dress'}), confidence=1.0, lift=2.5)])
# RelationRecord(items=frozenset({'Dress', 'Necklace'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Necklace'}), items_add=frozenset({'Dress'}), confidence=1.0, lift=2.5)])
# ...

# %%
# !pip uninstall mlxtend
# !pip install mlxtend==0.21.0
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Found existing installation: mlxtend 0.23.3
# Uninstalling mlxtend-0.23.3:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/mlxtend-0.23.3.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/mlxtend/*
# Proceed (Y/n)? Y
#   Successfully uninstalled mlxtend-0.23.3
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 18.5 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade mlxtend
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 20.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: mlxtend
#     Found existing installation: mlxtend 0.21.0
#     Uninstalling mlxtend-0.21.0:
#       Successfully uninstalled mlxtend-0.21.0
# ...

# %%
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd

# Sample toy dataset
toy_dataset = [
    ['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],
    ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],
    ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],
    ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],
    ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']
]

# Convert the toy dataset into the appropriate format for the apriori algorithm
te = TransactionEncoder()
te_ary = te.fit_transform(toy_dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

# Apply the Apriori algorithm
frequent_itemsets = apriori(df, min_support=0.5, use_colnames=True)

#
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0, num_itemsets=2)

# Display the frequent itemsets and association rules
print("Frequent Itemsets:")
print(frequent_itemsets)

print("\nAssociation Rules:")
print(rules)
# Out:
# Frequent Itemsets:
#    support        itemsets
# 0      0.6           (Hat)
# 1      0.8         (Pants)
# 2      0.8         (Scarf)
# 3      0.6         (Skirt)
# 4      0.6  (Pants, Scarf)
# 5      0.6  (Pants, Skirt)
#
# Association Rules:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Pants)     (Skirt)                 0.8                 0.6      0.6
# 1     (Skirt)     (Pants)                 0.6                 0.8      0.6
#
#    confidence  lift  representativity  leverage  conviction  zhangs_metric  \
# 0        0.75  1.25               1.0      0.12         1.6            1.0
# 1        1.00  1.25               1.0      0.12         inf            0.5
#
#    jaccard  certainty  kulczynski
# 0     0.75      0.375       0.875
# 1     0.75      1.000       0.875
# ...

# %%
import pandas as pd
import plotly.express as px

# Load dataset
df = pd.read_csv('/content/Market_Basket_Optimisation.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Automatically generate column names based on the number of columns
df.columns = [f'Item{i+1}' for i in range(len(df.columns))]

# Verify the dataframe with new column names
print(df.head())
# Out:
#             Item1      Item2       Item3             Item4      Item5 Item6  \
# 0         burgers  meatballs        eggs               NaN        NaN   NaN
# 1         chutney        NaN         NaN               NaN        NaN   NaN
# 2          turkey    avocado         NaN               NaN        NaN   NaN
# 3   mineral water       milk  energy bar  whole wheat rice  green tea   NaN
# 4  low fat yogurt        NaN         NaN               NaN        NaN   NaN
#
#   Item7 Item8 Item9 Item10 Item11 Item12 Item13 Item14 Item15 Item16 Item17  \
# 0   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#   Item18 Item19  Item20
# 0    NaN    NaN     NaN
# ...

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             Item1      Item2       Item3             Item4      Item5 Item6  \
# 0         burgers  meatballs        eggs               NaN        NaN   NaN
# 1         chutney        NaN         NaN               NaN        NaN   NaN
# 2          turkey    avocado         NaN               NaN        NaN   NaN
# 3   mineral water       milk  energy bar  whole wheat rice  green tea   NaN
# 4  low fat yogurt        NaN         NaN               NaN        NaN   NaN
#
#   Item7 Item8 Item9 Item10 Item11 Item12 Item13 Item14 Item15 Item16 Item17  \
# 0   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Item1   7500 non-null   object
#  1   Item2   5746 non-null   object
#  2   Item3   4388 non-null   object
#  3   Item4   3344 non-null   object
#  4   Item5   2528 non-null   object
#  5   Item6   1863 non-null   object
#  6   Item7   1368 non-null   object
#  7   Item8   980 non-null    object
#  8   Item9   653 non-null    object
#  9   Item10  394 non-null    object
#  10  Item11  255 non-null    object
#  11  Item12  153 non-null    object
#  12  Item13  86 non-null     object
#  13  Item14  46 non-null     object
#  14  Item15  24 non-null     object
#  15  Item16  7 non-null      object
#  16  Item17  3 non-null      object
#  17  Item18  3 non-null      object
#  18  Item19  2 non-null      object
#  19  Item20  0 non-null      float64
# dtypes: float64(1), object(19)
# ...

# %%
df.describe()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        Item20
# count     0.0
# mean      NaN
# std       NaN
# min       NaN
# 25%       NaN
# 50%       NaN
# 75%       NaN
# max       NaN

# %%
df.isnull().sum()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Item1        0
# Item2     1754
# Item3     3112
# Item4     4156
# Item5     4972
# Item6     5637
# Item7     6132
# Item8     6520
# Item9     6847
# Item10    7106
# Item11    7245
# Item12    7347
# Item13    7414
# Item14    7454
# Item15    7476
# Item16    7493
# Item17    7497
# Item18    7497
# Item19    7498
# Item20    7500
# dtype: int64

# %%
#Replacing missing values
for column in df.columns:
    if df[column].dtype == 'object':  # Categorical column
        df[column] = df[column].fillna('Unknown')
    elif df[column].dtype in ['int64', 'float64']:  # Numerical column
        df[column] = df[column].fillna(0)
    else:
        # Handle other data types if needed
        pass
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.isnull().sum()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Item1     0
# Item2     0
# Item3     0
# Item4     0
# Item5     0
# Item6     0
# Item7     0
# Item8     0
# Item9     0
# Item10    0
# Item11    0
# Item12    0
# Item13    0
# Item14    0
# Item15    0
# Item16    0
# Item17    0
# Item18    0
# Item19    0
# Item20    0
# dtype: int64

# %%
#list the most frequent items
# Assuming 'Item1' contains the item names
item_counts = df['Item1'].value_counts()
print("Most frequent items:")
print(item_counts)

import plotly.express as px

# Get the top 10 most frequent items
top_items = item_counts.head(10)

# Plot histogram for the top 10 most frequent items
fig = px.bar(top_items, x=top_items.index, y=top_items.values,
             labels={'x': 'Item Name', 'y': 'Count'},
             title="Top 10 Most Purchased Items")
fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Most frequent items:
# Item1
# mineral water        577
# burgers              576
# turkey               458
# chocolate            391
# frozen vegetables    373
#                     ...
# cauliflower            1
# ketchup                1
# cream                  1
# body spray             1
# oatmeal                1
# Name: count, Length: 115, dtype: int64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...
